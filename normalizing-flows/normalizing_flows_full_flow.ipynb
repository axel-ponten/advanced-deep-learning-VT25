# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt
import os
import time
import jammy_flows
from cnn import SimpleCNN
from B03train_normalizing_flow_template import CombinedModel, nf_loss
# Out:
# Meander not installed... contours can not be calculated.

# %%
data_path = "data"
flow_type = "full_flow" # ["diagonal_gaussian", "full_gaussian", "full_flow"]
model_folder = "models/" + flow_type
plot_folder = "plots/" + flow_type
os.makedirs(model_folder, exist_ok=True)
os.makedirs(plot_folder, exist_ok=True)
device="cuda" if torch.cuda.is_available() else "cpu"
print(f"Using {device} device")
print("CUDA version", torch.version.cuda)
# Out:
# Using cuda device
# CUDA version 12.4

# %%
l0 = 4718 # angstrom, start of spectrum
l1 = 7890 # angstrom, end of spectrum
spectra = np.load(f"{data_path}/spectra.npy")
# normalize
spectra = np.log(np.maximum(spectra, 0.2))
spectra_length = spectra.shape[1]
# labels: mass, age, l_bol, dist, t_eff, log_g, fe_h, SNR
labelNames = ["mass", "age", "l_bol", "dist", "t_eff", "log_g", "fe_h", "SNR"]
labels = np.load(f"{data_path}/labels.npy")
# We only use the three labels: t_eff, log_g, fe_h
labelNames = labelNames[-4:-1]
labels = labels[:, -4:-1]
# normalize labels
label_means = np.mean(labels, axis=0)
label_stds = np.std(labels, axis=0)
labels = (labels - label_means) / label_stds
n_labels = labels.shape[1]

# %%
print(spectra)
print(type(spectra))
print(spectra.shape) # 8914, 16384 (number of spectra, length of each spectrum)

print(labelNames)
print(labels)
print(labels.shape)
# Out:
# [[-0.0182943  -0.01366498  0.00676046 ...  0.06692334  0.10649246
#    0.20378247]
#  [-0.04135376 -0.06643463 -0.11676109 ...  0.00545667  0.07043431
#    0.20460529]
#  [-0.07064897 -0.02532261 -0.01220473 ...  0.03334754  0.09973088
#    0.2310698 ]
#  ...
#  [-0.02218651  0.00892046  0.01012168 ...  0.01696421  0.11753463
#    0.2195622 ]
#  [-0.1282717  -0.02985833  0.01431552 ...  0.00762445  0.06368124
#    0.198687  ]
#  [-0.03660118 -0.02355827 -0.01801771 ...  0.07393676  0.15408995
#    0.2704637 ]]
# <class 'numpy.ndarray'>
# (8914, 16384)
# ['t_eff', 'log_g', 'fe_h']
# [[ 0.49638405  0.62059     0.04494437]
#  [ 0.58323914  0.2617865   1.2484009 ]
#  [-0.69482577  0.87545943  0.0841229 ]
#  ...
#  [ 1.1606643   0.4199249  -0.12963866]
#  [ 0.46888962  0.36218032 -0.85537946]
#  [ 0.45096773  0.71121436 -0.76129895]]
# (8914, 3)

# %% [markdown]
# ### Visualize some spectra

# %%
x = np.linspace(l0, l1, spectra_length)
fig, axs = plt.subplots(4, sharex=True, figsize=(8, 8))

for i in range(4):
    axs[i].plot(x, spectra[i], linewidth=0.3, color="black")
    axs[i].set_title(f"{labelNames[0]}: {labels[i, 0]}, {labelNames[1]}: {labels[i, 1]}, {labelNames[2]}: {labels[i, 2]}", fontsize=8)
    axs[i].set_ylabel("Flux (norm.)")
    axs[i].set_xlabel(r"$\lambda \; [Å]$")
plt.tight_layout()
plt.savefig(os.path.join(plot_folder, "spectra.png"))

# %%
# visualize labels
fig, axs = plt.subplots(3, figsize=(4, 6))
for i in range(3):
    axs[i].hist(labels[:, i], bins=100, color="black", alpha=0.7)
    axs[i].set_title(labelNames[i])
plt.tight_layout()
plt.savefig(os.path.join(plot_folder, "labels_normalized.png"))

fig, axs = plt.subplots(3, figsize=(4, 6))
for i in range(3):
    reverse_normalized = labels[:, i] * label_stds[i] + label_means[i]
    axs[i].hist(reverse_normalized, bins=100, color="blue", alpha=0.7)
    axs[i].set_title(labelNames[i])
plt.tight_layout()
plt.savefig(os.path.join(plot_folder, "labels.png"))

# %% [markdown]
# ### Create dataset and dataloader

# %%
####### DATASET #######
input_tensor = torch.Tensor(spectra).unsqueeze(1).to(device) # add dim for 1 channel
print(input_tensor)
print(input_tensor.shape)
labels_tensor = torch.Tensor(labels).to(device)

full_dataset = torch.utils.data.TensorDataset(input_tensor, labels_tensor)
train_dataset, test_dataset = torch.utils.data.random_split(full_dataset, [0.8, 0.2])

####### DATA LOADER #######
batch_size = 64
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size = batch_size, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size = batch_size, shuffle=False)
# Out:
# tensor([[[-0.0183, -0.0137,  0.0068,  ...,  0.0669,  0.1065,  0.2038]],
#
#         [[-0.0414, -0.0664, -0.1168,  ...,  0.0055,  0.0704,  0.2046]],
#
#         [[-0.0706, -0.0253, -0.0122,  ...,  0.0333,  0.0997,  0.2311]],
#
#         ...,
#
#         [[-0.0222,  0.0089,  0.0101,  ...,  0.0170,  0.1175,  0.2196]],
#
#         [[-0.1283, -0.0299,  0.0143,  ...,  0.0076,  0.0637,  0.1987]],
#
#         [[-0.0366, -0.0236, -0.0180,  ...,  0.0739,  0.1541,  0.2705]]],
#        device='cuda:0')
# torch.Size([8914, 1, 16384])

# %% [markdown]
# ### Create model and loss

# %%
model = CombinedModel(SimpleCNN, inputdim=spectra_length, nf_type=flow_type)
model.to(device)
print(model)
total_params = sum([p.numel() for p in model.parameters() if p.requires_grad])
print("Trainable parameters", total_params)

####### LOSS AND OPTIMIZER #######

learning_rate = 0.8e-5
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# models = {}
# optimizers = {}
# for flow_type in ["diagonal_gaussian", "full_gaussian", "full_flow"]:
#     models[flow_type] = CombinedModel(SimpleCNN, inputdim=spectra_length, nf_type=flow_type)

#     print(models[flow_type])
#     total_params = sum([p.numel() for p in models[flow_type].parameters() if p.requires_grad])
#     print("Trainable parameters", total_params)

#     ####### LOSS AND OPTIMIZER #######

#     learning_rate = 0.8e-5
#     optimizers[flow_type] = torch.optim.Adam(models[flow_type].parameters(), lr=learning_rate)
# Out:
# sub-manifold (0 - e3 - gggt) and intra-manifold flow (0 - g) options overwrite  fit_normalization  with  1
# sub-manifold (0 - e3 - gggt) and intra-manifold flow (0 - g) options overwrite  upper_bound_for_widths  with  1.0
# sub-manifold (0 - e3 - gggt) and intra-manifold flow (0 - g) options overwrite  lower_bound_for_widths  with  0.01
# sub-manifold (0 - e3 - gggt) and intra-manifold flow (1 - g) options overwrite  fit_normalization  with  1
# sub-manifold (0 - e3 - gggt) and intra-manifold flow (1 - g) options overwrite  upper_bound_for_widths  with  1.0
# sub-manifold (0 - e3 - gggt) and intra-manifold flow (1 - g) options overwrite  lower_bound_for_widths  with  0.01
# sub-manifold (0 - e3 - gggt) and intra-manifold flow (2 - g) options overwrite  fit_normalization  with  1
# sub-manifold (0 - e3 - gggt) and intra-manifold flow (2 - g) options overwrite  upper_bound_for_widths  with  1.0
# sub-manifold (0 - e3 - gggt) and intra-manifold flow (2 - g) options overwrite  lower_bound_for_widths  with  0.01
# sub-manifold (0 - e3 - gggt) and intra-manifold flow (3 - t) options overwrite  cov_type  with  full
# The normalizing flow has  306  parameters...
# CombinedModel(
#   (pdf): pdf(
#     (layer_list): ModuleList(
#       (0): ModuleList(
#         (0-2): 3 x gf_block()
#         (3): mvn_block()
#       )
#     )
#     (mlp_predictors): ModuleList(
#       (0): None
#     )
#   )
#   (encoder): SimpleCNN(
#     (conv1): Conv1d(1, 2, kernel_size=(4,), stride=(1,), padding=same)
#     (pool): MaxPool1d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#     (conv2): Conv1d(2, 4, kernel_size=(4,), stride=(1,), padding=same)
#     (fc1): Linear(in_features=4096, out_features=128, bias=True)
#     (fc2): Linear(in_features=128, out_features=64, bias=True)
#     (output): Linear(in_features=64, out_features=306, bias=True)
#   )
# )
# Trainable parameters 552608

# %%
####### TRAIN #######
n_epochs = 400
print("Starting training loop with {} epochs".format(n_epochs))
train_losses = []
test_losses = []
best_test_loss = 99999999999
best_model = None
earlystop_counter = 0
earlystop_patience = 10
stop_now = False

for epoch in range(n_epochs):
    if stop_now:
        break
    start_time = time.time()
    train_loss = 0
    for i, (batch_input, batch_label) in enumerate(train_loader):
        model.train()
        # reset gradients
        optimizer.zero_grad()
        # propagate input
        output = model(batch_input)
        # compute loss
        loss = nf_loss(batch_input, batch_label, model)
        # compute gradient
        loss.backward()
        # update weights
        optimizer.step()
        # save loss
        train_loss += loss.item()
    ### END OF EPOCH ###
    # run validation
    with torch.no_grad():
        # val loss for the epoch
        test_loss = 0.0
        model.eval()  # Set the model to evaluation mode
        for batch_input, batch_label in test_loader:
            output = model(batch_input)
            loss = nf_loss(batch_input, batch_label, model)
            test_loss += loss.item()
        test_loss = test_loss/len(test_dataset)  # Calculate the average val loss
        test_losses.append(test_loss)
    # add losses
    train_loss = train_loss/len(train_dataset)  # Calculate the average train loss pe event
    train_losses.append(train_loss)
    end_time = time.time()
    if epoch % 10 == 0:
        # print progress
        print("Epoch", epoch, "train loss", train_loss, "test loss", test_loss, "time current epoch", end_time-start_time)
        # save model
        # model_path = os.path.join(model_folder, f"simpleCNN_epoch_{epoch}.pth")
        # torch.save(model.state_dict(), model_path)
        # plot loss
        plt.figure()
        plt.plot(train_losses, label="Train", linewidth=0.5)
        plt.plot(test_losses, label="Test", linewidth=0.5)
        plt.title("Astronomy CNN loss")
        plt.xlabel("Epoch")
        plt.ylabel("Average Event Loss")
        plt.yscale("log")
        plt.legend()
        plt.savefig(os.path.join(plot_folder, "loss.png"))
        plt.close()
    # EARLY STOPPING?
    if test_loss < best_test_loss:
        model_path = os.path.join(model_folder, "simpleCNN_best.pth")
        torch.save(model.state_dict(), model_path)
        best_model = model
        best_test_loss = test_loss
        earlystop_counter = 0
    else:
        earlystop_counter += 1
        if earlystop_counter > earlystop_patience:
            stop_now = True
            print("Early stopping at epoch", epoch, " with val loss", test_loss, " and best loss", best_test_loss)
            break
# Out:
# Starting training loop with 400 epochs
# /home/axel/advanced-deep-learning-VT25/.venv/lib/python3.10/site-packages/torch/nn/modules/conv.py:370: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at /pytorch/aten/src/ATen/native/Convolution.cpp:1036.)
#   return F.conv1d(
# Epoch 0 train loss 0.1635809679563886 test loss 0.1595751525053452 time current epoch 306.2897791862488
# Epoch 10 train loss 0.06945606541186194 test loss 0.0666850653912104 time current epoch 199.2272071838379
# Epoch 20 train loss 0.05698790450282236 test loss 0.05664059458214115 time current epoch 201.9306104183197
# Epoch 30 train loss 0.051827260702388675 test loss 0.05133324823567142 time current epoch 203.20807313919067
# Epoch 40 train loss 0.047714376506918475 test loss 0.04732840476137234 time current epoch 204.00636291503906
# Epoch 50 train loss 0.043472951571736605 test loss 0.043730444335578406 time current epoch 204.47051644325256
# Epoch 60 train loss 0.03778101840714876 test loss 0.039206946641827896 time current epoch 204.92374897003174
# Epoch 70 train loss 0.03474483081907267 test loss 0.034435230734261926 time current epoch 204.89635348320007
# Epoch 80 train loss 0.032197108935983106 test loss 0.03439993741055325 time current epoch 204.94365429878235
# Epoch 90 train loss 0.03000963855962117 test loss 0.030975379157758522 time current epoch 205.24400067329407
# Epoch 100 train loss 0.028481633827582366 test loss 0.02828863998949917 time current epoch 204.9615194797516
# Epoch 110 train loss 0.026613583129023493 test loss 0.027112261998408587 time current epoch 204.95004057884216
# Epoch 120 train loss 0.025065111329700497 test loss 0.02501944112199796 time current epoch 204.6009659767151
# Epoch 130 train loss 0.023339910143674106 test loss 0.024010320714721735 time current epoch 204.77565026283264
# Epoch 140 train loss 0.022257156272968048 test loss 0.022885554525308036 time current epoch 204.74182295799255
# Epoch 150 train loss 0.02041359813734541 test loss 0.020500318067027592 time current epoch 204.75344491004944
# Epoch 160 train loss 0.019299986583747868 test loss 0.023431888475657178 time current epoch 204.6980004310608
# Epoch 170 train loss 0.016869254265892395 test loss 0.017308884453019497 time current epoch 204.74027824401855
# Epoch 180 train loss 0.01597546234499069 test loss 0.016023729415220306 time current epoch 204.6541097164154
# Epoch 190 train loss 0.01495311002768155 test loss 0.014364082355207648 time current epoch 204.34031009674072
# Epoch 200 train loss 0.012792496158269103 test loss 0.013140712375008204 time current epoch 204.53450679779053
# Epoch 210 train loss 0.011889299715499378 test loss 0.01292757248355873 time current epoch 204.39781546592712
# Epoch 220 train loss 0.011641739231669612 test loss 0.018011440361449443 time current epoch 204.37527203559875
# Epoch 230 train loss 0.010106786374763956 test loss 0.011291422804492041 time current epoch 204.49986100196838
# Epoch 240 train loss 0.00932431925152977 test loss 0.010214007154782812 time current epoch 204.37886452674866
# Epoch 250 train loss 0.009741199150340373 test loss 0.008743189658305785 time current epoch 204.45187163352966
# Epoch 260 train loss 0.0088063595720284 test loss 0.014871386729837996 time current epoch 204.62124371528625
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 22
#      20 optimizer.zero_grad()
#      21 # propagate input
# ---> 22 output = model(batch_input)
#      23 # compute loss
#      24 loss = nf_loss(batch_input, batch_label, model)
#
# File ~/advanced-deep-learning-VT25/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/advanced-deep-learning-VT25/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/advanced-deep-learning-VT25/normalizing-flows/B03train_normalizing_flow_template.py:227, in CombinedModel.forward(self, input_data, samplesize_per_batchitem)
#     208 """
#     209 Perform a forward pass through the model, predicting the mean and standard deviation of the samples.
#     210
#    (...)
#     224     the second half (another D) are the standard deviations.
#     225 """
#     226 flow_params=self.encoder(input_data)
# --> 227 samples=self.sample(flow_params, samplesize_per_batchitem=samplesize_per_batchitem)
#     229 # form mean along dim 1 (samples)
#     230 means=samples.mean(dim=1)
#
# File ~/advanced-deep-learning-VT25/normalizing-flows/B03train_normalizing_flow_template.py:198, in CombinedModel.sample(self, flow_params, samplesize_per_batchitem)
#     196 batch_size = flow_params.shape[0] # get the batch size
#     197 # sample from the normalizing flow
# --> 198 repeated_samples, _, _, _ = self.pdf.sample(amortization_parameters=flow_params.repeat_interleave(
#     199     samplesize_per_batchitem, dim=0), allow_gradients=False)
#     201 # reshape the samples to be grouped by batch item
#     202 reshaped_samples = repeated_samples[:, None, :].view(
#     203     batch_size, samplesize_per_batchitem, -1)
#
# File ~/advanced-deep-learning-VT25/.venv/lib/python3.10/site-packages/jammy_flows/main/default.py:1329, in pdf.sample(self, conditional_input, samplesize, seed, allow_gradients, amortization_parameters, force_embedding_coordinates, force_intrinsic_coordinates, failsafe_crosscheck_tolerance, dtype, device)
#    1327 else:
#    1328     with torch.no_grad():
# -> 1329         sample, normal_base_sample, log_pdf_target, log_pdf_base=self._obtain_sample(conditional_input=conditional_input,
#    1330                                                                                      seed=seed,
#    1331                                                                                      samplesize=samplesize,
#    1332                                                                                      amortization_parameters=amortization_parameters,
#    1333                                                                                      force_embedding_coordinates=force_embedding_coordinates,
#    1334                                                                                      force_intrinsic_coordinates=force_intrinsic_coordinates,
#    1335                                                                                      failsafe_crosscheck_tolerance=failsafe_crosscheck_tolerance,
#    1336                                                                                      device=device,
#    1337                                                                                      dtype=dtype)
#    1339     return sample, normal_base_sample, log_pdf_target, log_pdf_base
#
# File ~/advanced-deep-learning-VT25/.venv/lib/python3.10/site-packages/jammy_flows/main/default.py:1631, in pdf._obtain_sample(self, conditional_input, predefined_target_input, samplesize, seed, amortization_parameters, force_embedding_coordinates, force_intrinsic_coordinates, failsafe_crosscheck_tolerance, dtype, device)
#    1627     x = std_normal_samples
#    1629 log_det = torch.zeros(used_sample_size).type(data_type).to(used_device)
# -> 1631 new_targets, log_det=self.all_layer_forward(x, log_det, conditional_input, amortization_parameters=amortization_parameters, force_embedding_coordinates=force_embedding_coordinates, force_intrinsic_coordinates=force_intrinsic_coordinates)
#    1633 ## failsafe crosscheck?
#    1635 return_log_pdf=-log_det + log_gauss_evals
#
# File ~/advanced-deep-learning-VT25/.venv/lib/python3.10/site-packages/jammy_flows/main/default.py:1460, in pdf.all_layer_forward(self, x, log_det, data_summary, amortization_parameters, force_embedding_coordinates, force_intrinsic_coordinates)
#    1458         this_target, log_det = layer.flow_mapping([this_target, log_det], extra_inputs=this_extra_params)
#    1459     else:
# -> 1460         this_target, log_det = layer.flow_mapping([this_target, log_det], extra_inputs=this_extra_params)
#    1462     extra_param_counter += layer.total_param_num
#    1464 new_targets.append(this_target)
#
# File ~/advanced-deep-learning-VT25/.venv/lib/python3.10/site-packages/jammy_flows/layers/euclidean/euclidean_base.py:76, in euclidean_base.flow_mapping(self, inputs, extra_inputs, force_embedding_coordinates, force_intrinsic_coordinates)
#      73         return [x+this_offset, logdet]
#      74 else:
# ---> 76     return self._flow_mapping(inputs, extra_inputs=extra_inputs)
#
# File ~/advanced-deep-learning-VT25/.venv/lib/python3.10/site-packages/jammy_flows/layers/euclidean/gaussianization_flow.py:920, in gf_block._flow_mapping(self, inputs, extra_inputs, verbose, lower, upper)
#     916 flow_params, rotation_params=self._obtain_usable_flow_params(z, extra_inputs=extra_inputs)
#     918 if(self.nonlinear_stretch_type=="classic"):
# --> 920     res=bn.inverse_bisection_n_newton_joint_func_and_grad(self.sigmoid_inv_error_pass_w_params, self.sigmoid_inv_error_pass_combined_val_n_normal_derivative, z, flow_params[0], flow_params[1],flow_params[2],flow_params[3],flow_params[4], min_boundary=lower, max_boundary=upper, num_bisection_iter=25, num_newton_iter=20)
#     921     log_deriv=self.sigmoid_inv_error_pass_log_derivative_w_params(res, flow_params[0], flow_params[1], flow_params[2], flow_params[3], flow_params[4])
#     923     log_det=log_det-log_deriv.sum(axis=-1)
#
# File ~/advanced-deep-learning-VT25/.venv/lib/python3.10/site-packages/jammy_flows/layers/bisection_n_newton.py:74, in inverse_bisection_n_newton_joint_func_and_grad(func, joint_func, target_arg, min_boundary, max_boundary, num_bisection_iter, num_newton_iter, newton_tolerance, verbose, *args)
#      70 broadcasting_bool_args=[True if (prev.shape[0]>1 and arg.shape[0]>1) else False for arg in args ]
#      72 for i in range(num_newton_iter):
# ---> 74     fn_result, f_prime_eval = joint_func(prev[above_tolerance_mask,:], *[a[above_tolerance_mask] if(broadcasting_bool_args[arg_index] == True) else a for arg_index, a in enumerate(args)])
#      76     f_eval=fn_result-target_arg[above_tolerance_mask,:]
#      78     update=(f_eval/f_prime_eval)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Plot losses

# %%
####### PLOT LOSS #######
plt.close()
plt.figure()
plt.plot(train_losses, label="Train", linewidth=0.5)
plt.plot(test_losses, label="Test", linewidth=0.5)
plt.title("Astronomy CNN+NF loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
# plt.ylim(-0.02, 0.08)
# plt.yscale("log")
plt.legend()
plt.savefig(os.path.join(plot_folder, "loss.png"))
plt.show()

# %% [markdown]
# ### Open best model and plot some predictions

# %%
# model_path = os.path.join(model_folder, "simpleCNN_best.pth")
# model.load_state_dict(torch.load(model_path))
model = best_model

# predict on test
model.eval()
pred = []
true = []
pull = []
std = []
errors = []
relative_errors = []
first_batch = True
with torch.no_grad():
    for i, (batch_input, batch_label) in enumerate(test_loader):
        output = model(batch_input)
        preds = output[:, :n_labels]
        _std = output[:, n_labels:]
        error = (preds - batch_label)
        _pull = error / _std
        # reverse normalization
        # error = error.cpu() * label_stds + label_means
        # batch_label = batch_label.cpu() * label_stds + label_means
        relative_error = error / batch_label
        # append
        true.append(batch_label)
        pred.append(preds)
        pull.append(_pull)
        std.append(_std)
        errors.append(error)
        relative_errors.append(relative_error)
        if first_batch:
            model.visualize_pdf(batch_input, filename=os.path.join(plot_folder, "pdf_example.png"))
            first_batch = False

true = torch.cat(true, dim=0).cpu().numpy()
pred = torch.cat(pred, dim=0).cpu().numpy()
errors = torch.cat(errors, dim=0).cpu().numpy()
pull = torch.cat(pull, dim=0).cpu().numpy()
std = torch.cat(std, dim=0).cpu().numpy()
relative_errors = torch.cat(relative_errors, dim=0).cpu().numpy()

# %%
fig, axs = plt.subplots(3, 1, figsize=(8, 8))
for i in range(3):
    axs[i].hist(errors[:, i] * label_stds[i], bins=80) # unnormalize (mean cancels, only need std)
    axs[i].set_title(labelNames[i])
    axs[i].set_xlabel("(pred - true)")
    axs[i].set_ylabel("Counts")
plt.tight_layout()
plt.savefig(os.path.join(plot_folder, "pred_errors.png"))

fig, axs = plt.subplots(3, figsize=(4, 6))
fig.suptitle("Train Normalized Target")
for i in range(3):
    axs[i].hist(true[:, i]* label_stds[i] + label_means[i], bins=80, alpha=0.7, label="True")
    axs[i].hist(pred[:, i]* label_stds[i] + label_means[i], bins=80, alpha=0.7, label="Pred")
    axs[i].set_title(labelNames[i])
plt.tight_layout()
plt.savefig(os.path.join(plot_folder, "pred.png"))

plt.show()

# %%
fig, axs = plt.subplots(1, 3, figsize=(12, 4))
# fig.suptitle("Predictions vs. True")
for i in range(3):
    axs[i].plot(true[:, i]* label_stds[i] + label_means[i], pred[:, i]* label_stds[i] + label_means[i], 'b.', markersize=0.5)
    axs[i].plot([label_means[i]-3*label_stds[i], label_means[i]+3*label_stds[i]], [label_means[i]-3*label_stds[i], label_means[i]+3*label_stds[i]], 'k--')
    axs[i].set_title(labelNames[i])
    axs[i].set_xlabel("True")
    axs[i].set_ylabel("Pred")
plt.tight_layout()
plt.savefig(os.path.join(plot_folder, "pred_vs_true.png"))

# %%
from scipy.optimize import curve_fit

def gauss_function(x, a, x0, sigma):
    return a*np.exp(-(x-x0)**2/(2*sigma**2))

xplot = np.linspace(-5, 5, 100)

# visualize pull
fig, axs = plt.subplots(3, figsize=(4, 6))
bins = np.linspace(-5, 5, 100)
for i in range(3):
    n, bins, patches = axs[i].hist(pull[:, i], bins=bins, alpha=0.7)
    # gaussian fit 
    popt, pcov = curve_fit(gauss_function, bins[:-1], n, p0=[1, 0, 1])
    mu = popt[1]
    sigma = popt[2]
    print("Gaussian fit parameters", popt)
    axs[i].plot(xplot, gauss_function(xplot, *popt), 'r--', label=r"$\mu$ = %.2f, $\sigma$ = %.2f" % (mu, abs(sigma)))
    axs[i].set_title(labelNames[i])
    axs[i].set_xlabel("(Pred - True) / std")
    axs[i].set_xlim(-5, 5)
    axs[i].legend()
plt.tight_layout()
plt.savefig(os.path.join(plot_folder, "pull.png"))
# Out:
# Gaussian fit parameters [219.5310495   -0.42838303  -0.24662856]
# Gaussian fit parameters [ 2.54720270e+02 -6.42297499e-01 -1.93742909e-01]
# Gaussian fit parameters [194.78182591  -0.40033997   0.28666042]
